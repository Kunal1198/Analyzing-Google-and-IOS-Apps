# %%
import pandas as pd

# %%
df=pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
from csv import reader

# The Google Play data set 
opened_file = open('googleplaystore.csv')
read_file = reader(opened_file)
android = list(read_file)
android_header = android[0]
android = android[1:]

# The App Store data set
opened_file = open('AppleStore.csv')
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios = ios[1:]

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.Rating            
#sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
# 5        4.4
# 6        3.8
# 7        4.1
# 8        4.4
# 9        4.7
# 10       4.4
# 11       4.4
# 12       4.2
# 13       4.6
# 14       4.4
# 15       3.2
# 16       4.7
# 17       4.5
# 18       4.3
# 19       4.6
# 20       4.0
# 21       4.1
# 22       4.7
# 23       NaN
# 24       4.7
# 25       4.8
# 26       4.7
# 27       4.1
# 28       3.9
# 29       4.1
#         ...
# 10811    NaN
# 10812    4.1
# 10813    NaN
# 10814    4.0
# 10815    4.2
# 10816    NaN
# 10817    4.0
# 10818    NaN
# 10819    3.3
# 10820    5.0
# 10821    NaN
# 10822    NaN
# 10823    NaN
# 10824    NaN
# 10825    NaN
# 10826    4.0
# 10827    4.2
# 10828    3.4
# 10829    4.6
# 10830    3.8
# 10831    NaN
# 10832    3.8
# 10833    4.8
# 10834    4.0
# 10835    NaN
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
header_length = len(android_header)
for row in android:
    rowlength = len(row) 
    if rowlength != header_length:
        print(row)
        print(android.index(row))
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# 10472

# %%
del android[10472]
print(len(android))
# Out:
# 10840

# %%
for app in android:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# # Removing Duplicate Entries

# %%
duplicate_apps = []
unique_apps = []

for app in android:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
    
print('Number of duplicate apps:', len(duplicate_apps))
print('\n')
print('Examples of duplicate apps:', duplicate_apps[:10])
# Out:
# Number of duplicate apps: 1181
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack']

# %%
reviews_max={}
for i in android:
    name=i[0]
    n_reviews=float(i[3])
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name]=n_reviews 
    elif name not in reviews_max:
        reviews_max[name]=n_reviews

# %%
print(reviews_max)
# Out:
# {'Programming Hub, Learn to code': 55704.0, 'Match™ Dating - Meet Singles': 76646.0, 'AQ Service': 4.0, 'English words application mikan': 9888.0, 'BG TV Program': 1.0, "Kinot Tisha'a Be'av - Ashkenaz": 82.0, 'Alba Heaven - Alvarez Job Portal Services': 8941.0, 'R Language Reference Guide': 54.0, 'AF Nutrition - Integratori': 6.0, 'Bluetooth Auto Connect': 20829.0, 'Control Center iOS 11 - Phone X notifications': 514.0, 'XOS - Launcher,Theme,Wallpaper': 49657.0, 'EBook For SAP BW ON HANA Learning Free': 0.0, 'Learn JavaScript': 25183.0, 'Weather –Simple weather forecast': 40606.0, 'FD VR - Virtual Photo Gallery': 179.0, 'FG Radio - Radios de France': 0.0, 'ER': 2.0, 'EZ-SEE': 71.0, 'Super Hearing Super Ear Amplifier': 21.0, 'TeamWard – live help for LoL': 3136.0, 'All Football - Latest News & Videos': 152867.0, 'Lamp detector': 5.0, 'Cash, Inc. Money Clicker Game & Business Adventure': 549720.0, 'Sworkit: Workouts & Fitness Plans': 109756.0, 'Peak – Brain Games & Training': 272321.0, 'FML F*ck my life + widget': 1415.0, 'CG Job Alerts': 116.0, 'AJ렌터카 법인 카셰어링': 0.0, 'Wolf of the BF:Commando MOBILE': 32.0, 'Keep My Notes - Notepad & Memo': 122424.0, '100 Doors of Revenge': 105766.0, 'Wedding Countdown Widget': 7376.0, 'Cardinal Glennon ER Reference': 19.0, 'Car G-Force Meter': 184.0, 'Fr Lupupa Sermons': 19.0, 'A.J. Styles HD Wallpapers 2018': 1.0, 'INTERKINOIS.CD': 1.0, 'YAKALA AY': 0.0, 'Piczle Lines DX': 281.0, 'App vault': 25094.0, 'Kiss Me! Lip Kissing Test': 191.0, 'Hercules CP Mobile': 20.0, 'Learn Spanish - Español': 32346.0, 'FD Calculator | Term Deposit | Fixed Deposit': 12.0, 'F-Stop Gallery Pro': 1302.0, 'Norwegian For Kids & Babies F': 0.0, 'Fruit Block - Puzzle Legend': 125647.0, 'Channel 19': 916.0, 'AC remote control mobile': 3043.0, 'Verify - Receipts & Expenses': 413.0, 'Cossack Dictionary (DN)': 7.0, 'BK Suraj bhai': 9.0, 'DB BAHN': 4.0, 'AW Connect': 0.0, 'CABLE SIZE CALCULATOR BS 7671': 333.0, 'CB Mobile Biz': 3.0, 'Free intellectual training game application |': 5741.0, 'X Launcher: With OS11 Style Theme & Control Center': 5754.0, 'BlitzWolf Shutter - BW Shutter': 333.0, 'CB TV': 2.0, 'Magoosh GMAT Prep & Practice': 1058.0, 'Racing Moto': 697805.0, '4 x4 Offroad SUV 3D Truck Simulator Driving 2017': 32.0, 'Teeny Titans - Teen Titans Go!': 20463.0, 'Princess Coloring Book': 9779.0, 'Photo Editor Collage Maker Pro': 1519671.0, 'BH Patrole': 27.0, 'ClanHQ': 560.0, 'Recipes and tips for losing weight': 35.0, 'Deck Shop for Clash Royale': 2167.0, 'The Grand Wars: San Andreas': 29990.0, 'Download Facebook Photo Albums': 3840.0, 'Driving Zone': 51791.0, 'BV Bombers': 0.0, 'trip.bg': 103.0, 'CNBC: Breaking Business News & Live Market Data': 24666.0, 'T map (te map, T map, navigation)': 15681.0, 'Sci-Fi Sounds and Ringtones': 128.0, 'Facebook Ads Manager': 19051.0, 'CASE K-12 Math English Science': 60.0, 'Lose Belly Fat in 30 Days - Flat Stomach': 38098.0, 'POGO Games': 32600.0, 'F-1 watchface by Delta': 0.0, 'FunnyPixels - Color by number Sandbox': 1977.0, 'BV Sridhara Maharaj': 8.0, 'Binaural Beats Meditation': 411.0, 'Terminal Emulator for Android': 113951.0, 'Amex Mobile': 24729.0, 'EZ-Builder Mobile': 51.0, 'File Viewer for Android': 7063.0, 'Crew - Free Messaging and Scheduling': 4159.0, 'Ah !': 3.0, 'WiFi Baby Monitor - NannyCam': 29867.0, 'Equestria Girl Snapchat Addict': 20.0, 'Zoopla Property Search UK - Home to buy & rent': 21195.0, 'Photo Editor': 114680.0, 'Autool BT-BOX': 4.0, 'ESLock File Recovery Lite': 460.0, 'JStock - Stock Market, Portfolio & News': 11066.0, 'PLAYBULB X': 2160.0, 'BS MAPS': 6.0, 'Metro name iD': 27800.0, 'EZ Usenet for Easynews®': 244.0, 'Fitbit': 357417.0, 'Caf - My Account': 18961.0, 'bX Hot Articles by Ex Libris': 42.0, 'TFO BZ Lessons': 75.0, 'Home Scouting® MLS Mobile': 1533.0, 'Novinky.cz': 2375.0, 'X your Ex - Break Up Treatment': 32.0, 'Barisal University App-BU Face': 100.0, 'Filters for Selfie': 8572.0, 'Cooking Fever': 3198176.0, 'Anatomy & Physiology Vocabulary Exam Re ...

# %%
print('length:', len(reviews_max))
# Out:
# length: 9659

# %%
android_clean = []
already_added = []

for app in android:
    name = app[0]
    n_reviews = float(app[3])
    
    if (reviews_max[name] == n_reviews) and (name not in already_added):
        android_clean.append(app)
        already_added.append(name)

# %%
print(len(android_clean))
# Out:
# 9659

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') 
        
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
explore_data(android_clean, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %% [markdown]
# # Removing Non-English Apps

# %%
def is_english(string):
    non_ascii = 0
    
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True
    
android_english = []
ios_english = []

for app in android_clean:
    name = app[0]
    if is_english(name):
        android_english.append(app)
        
for app in ios:
    name = app[1]
    if is_english(name):
        ios_english.append(app)

# %%
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 6183
# Number of columns: 16

# %%
free_apps=[]
for app in android_english:
    if app[7]=='0':
        free_apps.append(app)

# %%
free_ios_apps=[]
for app in ios_english:
    if app[4]=='0.0':
        free_ios_apps.append(app)

# %%
print(len(free_apps))
print(len(free_ios_apps))
# Out:
# 8864
# 3222

# %% [markdown]
# # Now we are left with 8864 Android apps and 3222 iOS apps

# %%
def freq_table(dataset, index):
    table = {}
    total = 0
    
    for row in dataset:
        total += 1
        value = row[index]
        if value in table:
            table[value] += 1
        else:
            table[value] = 1
    
    table_percentages = {}
    for key in table:
        percentage = (table[key] / total) * 100
        table_percentages[key] = percentage 
    
    return table_percentages


def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)
        
    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# # Analyzing the frequency for the prime_genre of IOS and Google Play Apps

# %%
display_table(free_ios_apps, -5)
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %%
display_table(free_apps, 1)
# Out:
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# EVENTS : 0.7107400722021661
# PARENTING : 0.6543321299638989
# ART_AND_DESIGN : 0.6430505415162455
# COMICS : 0.6204873646209386
# BEAUTY : 0.5979241877256317
